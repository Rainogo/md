# %% [markdown]
# # Agrupamiento K Means con Python
#
# Agrupamiento K Means es un algoritmo de aprendizaje no supervisado que intenta agrupar los datos en función de su similitud. El aprendizaje no supervisado significa que no hay ningún resultado que predecir, y el algoritmo simplemente trata de encontrar patrones en los datos. En el agrupamiento K Means, tenemos que especificar el número de clústeres en los que queremos agrupar los datos. El algoritmo asigna aleatoriamente cada observación a un clúster y encuentra el centroide de cada clúster. Luego, el algoritmo itera a través de dos pasos:
# Reasigna los puntos de datos al clúster cuyo centroide es el más cercano. Calcula el nuevo centroide de cada grupo. Estos dos pasos se repiten hasta que la variación dentro del clúster no se puede reducir más. La variación dentro del clúster se calcula como la suma de la distancia euclidiana entre los puntos de datos y sus respectivos centroides de clúster.

# %% [markdown]
# ## Importación de Librerias

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creación de algunos datos

# %%
from sklearn.datasets import make_blobs

# %%
# Creación de datos, 5 muestras, 2 características, 3 centroides (3 grupos)

data0 = make_blobs(n_samples=5, n_features=2, 
                           centers=3, cluster_std=1.8,random_state=101)

# %%
# matriz de características
data0[0]
# Out:
# array([[  4.04519119,   5.31196755],
#        [  1.49998486,   0.83857926],
#        [-13.06321831,  -5.23734717],
#        [ -8.47865118,  -7.62976784],
#        [ -1.19856602,   2.50408937]])

# %%
# Grupo asignado a cada entrada
data0[1]
# Out:
# array([2, 0, 1, 1, 0])

# %%
data0[0][:,0]
# Out:
# array([  4.04519119,   1.49998486, -13.06321831,  -8.47865118,
#         -1.19856602])

# %%
data0[0][:,1]
# Out:
# array([ 5.31196755,  0.83857926, -5.23734717, -7.62976784,  2.50408937])

# %%
plt.scatter(data0[0][:,0],data0[0][:,1],c=data0[1],cmap='rainbow')

# %%
# Creación de datos
data = make_blobs(n_samples=500, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=101)

# %% [markdown]
# ## Visualización de datos

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# ## Creación de Clústeres

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 4.02990778,  6.46842749],
#        [-9.32196425, -6.71138919],
#        [-3.38886866,  7.80216133],
#        [ 0.2487507 ,  1.56311978]])

# %%
kmeans.labels_
# Out:
# array([0, 1, 0, 0, 0, 2, 0, 0, 0, 3, 2, 3, 3, 1, 1, 0, 3, 3, 0, 2, 0, 3,
#        2, 1, 2, 2, 0, 3, 3, 3, 1, 0, 2, 3, 0, 3, 2, 1, 1, 0, 0, 2, 0, 0,
#        2, 3, 0, 0, 1, 3, 2, 0, 1, 0, 1, 0, 1, 2, 3, 0, 1, 0, 0, 2, 1, 3,
#        3, 1, 1, 3, 1, 0, 2, 0, 1, 2, 2, 0, 3, 0, 2, 0, 2, 3, 0, 3, 2, 3,
#        3, 3, 1, 0, 2, 0, 1, 3, 2, 0, 2, 2, 1, 3, 1, 2, 0, 0, 1, 1, 2, 1,
#        0, 3, 3, 1, 2, 0, 2, 3, 3, 0, 1, 1, 2, 0, 3, 2, 3, 1, 2, 0, 3, 3,
#        1, 1, 1, 2, 0, 2, 1, 1, 0, 0, 3, 0, 0, 3, 0, 2, 1, 1, 0, 1, 1, 3,
#        2, 2, 2, 2, 0, 3, 2, 2, 2, 2, 0, 0, 0, 0, 3, 2, 2, 3, 1, 2, 0, 0,
#        0, 1, 3, 1, 0, 1, 3, 1, 0, 1, 2, 1, 2, 0, 3, 3, 1, 3, 2, 2, 3, 0,
#        2, 2, 1, 0, 3, 2, 2, 0, 2, 1, 1, 3, 1, 2, 0, 2, 2, 1, 1, 2, 0, 0,
#        3, 1, 3, 3, 1, 3, 2, 0, 3, 0, 3, 0, 0, 0, 0, 1, 1, 3, 1, 3, 3, 2,
#        3, 1, 1, 1, 3, 3, 3, 2, 0, 2, 1, 3, 2, 0, 0, 1, 1, 3, 0, 3, 0, 0,
#        2, 2, 2, 1, 0, 1, 2, 2, 0, 0, 2, 2, 3, 2, 3, 2, 1, 2, 2, 3, 3, 1,
# ...

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# Debe tener en cuenta que los colores carecen de significaco en relación entre las dos columnas.

# %% [markdown]
# # ¡Buen trabajo!
